# %%
import sys, os
sys.path.append(os.path.abspath(".."))

from src.etl_module import get_spark_session
spark = get_spark_session()
spark.sql("SELECT country, count(*) FROM youtube_db.cleaned_videos GROUP BY country").show()
# Out:
# +-------+--------+
# |country|count(1)|
# +-------+--------+
# |     RU|   40739|
# |     DE|   40840|
# |     CA|   40881|
# |     MX|   40451|
# |     FR|   40724|
# |     IN|   37345|
# |     JP|   20523|
# |     KR|   34567|
# |     US|   40949|
# |     GB|   38916|
# +-------+--------+
